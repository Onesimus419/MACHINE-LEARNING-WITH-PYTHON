# %% [markdown]
# <a href="https://colab.research.google.com/github/Onesimus419/MACHINE-LEARNING-WITH-PYTHON/blob/main/weekend_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # Student:Joseph O. Borbor - 25 May 2026
# Problem 1

Liberia = 1847
print(Liberia) #This prints 1847 because it represents the variable Liberia.
print("Liberia") #This prints Liberia because the quotation mark shows the specification.
# Out:
# 1847
# Liberia

# %%
# Problem 2
country = "Liberia"
print(country)
print(country, "became independent in 1847")
# Out:
# Liberia
# Liberia became independent in 1847

# %%
# Problem 3
print('The year is"1847"')
# Out:
# The year is"1847"

# %%
# Problem 4
market_name = "Gobachop Market" #string
total_market_table = 150
price_per_bag = 3200.50         #decimal number
is_market_open = True

print("Market name:", market_name)
print("Total market tables:", total_market_table)
print("Price per bag:", price_per_bag)
print("Is market open:", is_market_open)

print("Type of market_name", type(market_name))
print("Type of total_market_table", type(total_market_table))
print("Type of price_per_bag", type(price_per_bag))
print("Type of is_market_open", type(is_market_open))
# Out:
# Market name: Gobachop Market
# Total market tables: 150
# Price per bag: 3200.5
# Is market open: True
# Type of market_name <class 'str'>
# Type of total_market_table <class 'int'>
# Type of price_per_bag <class 'float'>
# Type of is_market_open <class 'bool'>

# %%
# Problem 5
current_price = 2550.75
quantity = 10
total_cost = current_price * quantity
print("Total cost for 10 bags:", total_cost, "LRD")
# Out:
# Total cost for 10 bags: 25507.5 LRD

# %%
# Problem 6
has_scarcity = False
is_rainy = True

print("Scarcity today:", has_scarcity)
print("Rainy today:",is_rainy)
# Out:
# Scarcity today: False
# Rainy today: True

# %%
# Problem 7
price_per_bag_cassava = 800
quantity_cassava = 25
total_revenue = price_per_bag_cassava * quantity_cassava
print("Total revenue for Cassava sales:", total_revenue, "LRD")
# Out:
# Total revenue for Cassava sales: 20000 LRD

# %%
# Problem 8
today_price = 3200
increase = 150
tomorrow_price = today_price + increase
print("Tomorrow's rice price:", tomorrow_price, "LRD")
#
# Out:
# Tomorrow's rice price: 3350 LRD

# %%
# Problem 9
total_onion_cost = 1800
numbers_of_traders = 3
cost_per_trader = total_onion_cost / numbers_of_traders
print("Cost per trader for the shared bags of unions:", cost_per_trader, "LRD")
# Out:
# Cost per trader for the shared bags of unions: 600.0 LRD

# %%
# Problem 10
original_price = 2500
discount_rate = 0.10   #10% written as a decimal numeral.
discount_amount = original_price * discount_rate
final_price = original_price - discount_amount
print("Discount amount subtracted price:", discount_amount, "LRD")
print("Final price for palm oil after discount:", final_price, "LRD")
# Out:
# Discount amount subtracted price: 250.0 LRD
# Final price for palm oil after discount: 2250.0 LRD

# %%
# Problem 11
item = "cassava"
price = 800

print(item)      #prints the word: cassava
print("item")    #prints the word:item
print(price)     #prints the value:800
print("price")   #prints the word:price
# Out:
# cassava
# item
# 800
# price

# %%
# Problem 12
product = "pepper"
cost = 150.50
print("One bag of", product, "costs", cost, "LRD")
#
# Out:
# One bag of pepper costs 150.5 LRD

# %%
# Bonus Problem
Liberia = 1847
print("Liberia became independent in", Liberia)
print('"Liberia is', Liberia, 'years old"')
# Out:
# Liberia became independent in 1847
# "Liberia is 1847 years old"

# %% [markdown]
# Homework ASSIGNMENT 2

# %%
# Question 1_A_B
transport_cost = "750"
total_delivery_cost = int(transport_cost) + 250
print(f"Ma Christiana, your final shipping cost is: {total_delivery_cost} LRD.")
# Out:
# Ma Christiana, your final shipping cost is: 1000 LRD.

# %%
# Question 2_A_B
# A flat like [45,12,88] is 1D.
# Machine Learning models expect input X as a 2D matrix/table with row and columns, like a spreadsheet.
# Think of it like a delivery truck: it needs items packed in a crate with defined rows and columns, not loose on truck bed.
# The model needs the shape (n_simple, n-features).

#B
loose_stock =[[45],[12],[88]]
shipping_crate = [[45],[12],[8]]
print (shipping_crate)
print(loose_stock)
# Out:
# [[45], [12], [8]]
# [[45], [12], [88]]

# %%
# Question 3_A_B

yield_model_configs = {
    "engine_type": "Decision Tree",
    "max_depth_layers": 15,
    "strick_mode": True
}
print(yield_model_configs["engine_type"])
print(yield_model_configs["max_depth_layers"])
print(yield_model_configs["strick_mode"])

# F-string
print(f"system check: Turning engine depth to {yield_model_configs['max_depth_layers']}")
# Out:
# Decision Tree
# 15
# True
# system check: Turning engine depth to 15

# %%
# 4_A_B
# gobachop_data.shape vs
# gobachop_data_.shape() Use
# gobachop_data.shape without()

# Explanation using Delivery Truck Analogy:

 # An attribute like .shape is a description of the truck-it tells you how many rows and columns exist right now. You just read it.
 # A method like .shape() would be an action the truck performs.
 # Since .shape is an attribute, adding() causes an error: TypeError: 'tuple'
 # object is not collable.

 # B. Command to get top row

import pandas as pd

gobachop_data = pd.DataFrame({
    "vendor": ["Ma Musu", "Sia", "Kumba"],
    "Sales": [4000, 9500, 1500],
})
print("This is the shape of the data:", gobachop_data.shape)
print("\n")
print("This is the first row of the data:", "\n", gobachop_data.head(1))
print("\n")
print("This is the first three rows of the data:", "\n", gobachop_data.head(3))
print("\n")
print("This is the last three rows of the data:", "\n", gobachop_data.tail())
# Out:
# This is the shape of the data: (3, 2)
#
#
# This is the first row of the data:
#      vendor  Sales
# 0  Ma Musu   4000
#
#
# This is the first three rows of the data:
#      vendor  Sales
# 0  Ma Musu   4000
# 1      Sia   9500
# 2    Kumba   1500
#
#
# This is the last three rows of the data:
#      vendor  Sales
# 0  Ma Musu   4000
# 1      Sia   9500
# 2    Kumba   1500
