# %% [markdown]
# <a href="https://colab.research.google.com/github/Onesimus419/MACHINE-LEARNING-WITH-PYTHON/blob/main/Orientation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of addition

# %%
a = 2
b = 3
c = 2+3
print(c)
# Out:
# 5

# %% [markdown]
# Example of string

# %%
Greetings= "Advice na, pror"
print(Greetings)
# Out:
# Advice na, pror
